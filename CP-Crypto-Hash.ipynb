# %% [markdown]
# Add description of problem here

# %%
value = 954715275263692800

# %%
from IPython.display import Image
Image("http://www.jamesebechtold.com/WikiJB/ascii_files/ascii_table.jpg")

# %%
def dec_char(char):
    char = char - 1
    if char < 35:
        return 126
    return char

# %%
start_value = 126
test_value = value
result_string = []
for i in range(0,100):
    if test_value == 1:
        print("the password is: %s"%''.join(result_string))
        break
    if test_value % start_value == 0:
        test_value = test_value / start_value
        print("%c %d"%(chr(start_value), test_value))
        result_string.append(chr(start_value))
    else:
        start_value = dec_char(start_value)
else:
    print("Could not find password")
# Out:
# y 7890208886476800
# x 65751740720640
# x 547931172672
# u 4683172416
# t 40372176
# t 348036
# a 3588
# \ 39
# ' 1
# the password is: yxxutta\'
